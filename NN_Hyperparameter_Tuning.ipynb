# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagar856/Data-Science-Notes/blob/main/NN_Hyperparameter_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
# Load dataset
dataset = np.loadtxt('/content/pima-indians-diabetes.data.csv', delimiter=",")

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2             3             4  \
# count  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02
# mean  -8.789266e-17 -9.251859e-18  1.503427e-17  8.211024e-17 -4.972874e-17
# std    1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00 -3.572597e+00 -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01 -3.673367e-01 -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01  1.496408e-01  1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01  5.632228e-01  7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00  2.734528e+00  4.921866e+00  6.652839e+00
#
#                   5             6             7
# count  7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.960595e-15  1.905883e-15  2.081668e-16
# std    1.000652e+00  1.000652e+00  1.000652e+00
# min   -4.060474e+00 -1.189553e+00 -1.041549e+00
# 25%   -5.955785e-01 -6.889685e-01 -7.862862e-01
# 50%    9.419788e-04 -3.001282e-01 -3.608474e-01
# 75%    5.847705e-01  4.662269e-01  6.602056e-01
# max    4.455807e+00  5.883565e+00  4.063716e+00

# %% [markdown]
# ## Tuning of Hyperparameters : Batch Size and Epoch

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras) (23.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.2.0)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0

# %%
# Import packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.optimizers import Adam

# %%
# Create Model
def create_model():
  model = Sequential()
  model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
  model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
  model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

  adam = Adam(learning_rate=0.01)
  model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
  return model

# %%
# Create model
model = KerasClassifier(build_fn = create_model, verbose=0)
# Define the grid search parameters
batch_size = [10,20,30]
epochs = [10,50,100]
# Make the dictionary of grid search parameters
param_grid = dict(batch_size=batch_size, epochs=epochs)

# Build and fit GridSearchCV
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv = KFold(), verbose=5)
grid_result = grid.fit(X_standardized, y)

# %%
# Summarize the results
print('Best: {}, using: {}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
  print('{}, {} with: {}'.format(mean, stdev, param))
# Out:
# Best: 0.7774382480264832, using: {'batch_size': 20, 'epochs': 10}
# 0.7670401493930906, 0.05517362376184513 with: {'batch_size': 10, 'epochs': 10}
# 0.7618198794669383, 0.03884341295560071 with: {'batch_size': 10, 'epochs': 50}
# 0.7475171886936591, 0.04137571772244512 with: {'batch_size': 10, 'epochs': 100}
# 0.7774382480264832, 0.043013098096244796 with: {'batch_size': 20, 'epochs': 10}
# 0.7578983108394872, 0.03908615155666879 with: {'batch_size': 20, 'epochs': 50}
# 0.752652576181988, 0.03572537343226751 with: {'batch_size': 20, 'epochs': 100}
# 0.7696375519904932, 0.04320354655487485 with: {'batch_size': 30, 'epochs': 10}
# 0.7579322638146166, 0.05286808179435514 with: {'batch_size': 30, 'epochs': 50}
# 0.7605042016806722, 0.0429767419202424 with: {'batch_size': 30, 'epochs': 100}

# %% [markdown]
# ## Tuning of Hyperparameters : Learning rate & Dropout rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate, dropout_rate):
  model = Sequential()
  model.add(Dense(8, input_dim = 8, kernel_initializer='normal', activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(4, input_dim= 8, kernel_initializer = 'normal', activation='relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(1, activation='sigmoid'))

  adam = Adam(learning_rate = learning_rate)
  model.compile(loss= 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

# Create model

model = KerasClassifier(build_fn = create_model , verbose = 0, batch_size = 20, epochs= 10, learning_rate = [0.001, 0.01, 0.1], dropout_rate = [0.0, 0.1, 0.2])

# Define the grid search parameters

# learning_rate = [0.001, 0.01, 0.1]
# dropout_rate = [0.0, 0.1, 0.2]

# Make a dictionary of grid search parameters

param_grid = dict(learning_rate= learning_rate, dropout_rate = dropout_rate)

# Build and fit the grid search cv

grid = GridSearchCV(estimator= model, param_grid = param_grid, cv = KFold(), verbose = 5)
grid_result = grid.fit(X_standardized, y)

# %%
# Summerize the results
print('Best: {}, using: {}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{}, {}, with : {}'.format(mean, stdev, param))
# Out:
# Best: 0.7696545284780579, using: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7460572107630932, 0.05530262215024485, with : {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7696545284780579, 0.05125362698381622, with : {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7383668618962738, 0.05360408679736712, with : {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.7591885238944063, 0.03702459654717801, with : {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7371190900602665, 0.06554970624716877, with : {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7213903743315508, 0.0233238590467078, with : {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7605042016806722, 0.04545615034625589, with : {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7657074951192598, 0.04768866236811669, with : {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.6991511756217639, 0.05022039574610123, with : {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# ## Tuning of Hyperparameters : Activation Function & Kernel Initializer

# %%
# Defining the model

def create_model(activation_function, kernel_initializer):
  model = Sequential()
  model.add(Dense(8, input_dim = 8, kernel_initializer = kernel_initializer, activation = activation_function))
  model.add(Dense(4, input_dim= 8, kernel_initializer = kernel_initializer, activation = activation_function))
  model.add(Dense(1, activation='sigmoid'))

  adam = Adam(learning_rate = 0.01)
  model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

# Create the model

model = KerasClassifier(build_fn = create_model, verbose = 0, batch_size = 20, epochs = 10, activation_function = ['softmax', 'relu', 'tanh', 'linear'], kernel_initializer = ['uniform', 'normal', 'zero'])

# Define the grid search parameters
activation_function = ['softmax', 'relu', 'tanh', 'linear']
kernel_initializer = ['uniform', 'normal', 'zero']

# Make a dictionary of grid search parameters
param_grid = dict(activation_function = ['softmax', 'relu', 'tanh', 'linear'], kernel_initializer = ['uniform', 'normal', 'zero'])

# Build and fit grid search CV

grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(), verbose = 0)
grid_result = grid.fit(X_standardized, y)

# %%
# Summarize the results
print('Best: {}, using : {}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{}, {}, using:{}'.format(mean,stdev,param))
# Out:
# Best: 0.7748578219166455, using : {'activation_function': 'relu', 'kernel_initializer': 'normal'}
# 0.7591970121381886, 0.03609889912127852, using:{'activation_function': 'softmax', 'kernel_initializer': 'uniform'}
# 0.7578983108394873, 0.04340911937408291, using:{'activation_function': 'softmax', 'kernel_initializer': 'normal'}
# 0.7448688566335624, 0.034719693797489196, using:{'activation_function': 'softmax', 'kernel_initializer': 'zero'}
# 0.7592224768695357, 0.049790661888329625, using:{'activation_function': 'relu', 'kernel_initializer': 'uniform'}
# 0.7748578219166455, 0.05332923425325097, using:{'activation_function': 'relu', 'kernel_initializer': 'normal'}
# 0.6511586452762923, 0.05244525561493349, using:{'activation_function': 'relu', 'kernel_initializer': 'zero'}
# 0.7565911212970036, 0.03785042390953481, using:{'activation_function': 'tanh', 'kernel_initializer': 'uniform'}
# 0.7708938120702826, 0.03844673538188243, using:{'activation_function': 'tanh', 'kernel_initializer': 'normal'}
# 0.6511586452762923, 0.05244525561493349, using:{'activation_function': 'tanh', 'kernel_initializer': 'zero'}
# 0.7709192768016297, 0.03686886641409925, using:{'activation_function': 'linear', 'kernel_initializer': 'uniform'}
# 0.7682709447415329, 0.0328493060361274, using:{'activation_function': 'linear', 'kernel_initializer': 'normal'}
# 0.6511586452762923, 0.05244525561493349, using:{'activation_function': 'linear', 'kernel_initializer': 'zero'}

# %% [markdown]
# ## Tuning of Hyperparameters : Number of neurons in activation layer

# %%
# defining the model

def create_model(neuron1, neuron2):
  model = Sequential()
  model.add(Dense(neuron1, input_dim = 8, kernel_initializer = 'uniform', activation = 'tanh'))
  model.add(Dense(neuron2, input_dim = 8, kernel_initializer = 'uniform', activation = 'tanh'))
  model.add(Dense(1, activation = 'sigmoid'))

  adam = Adam(learning_rate = 0.01)
  model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

# Create the model

model = KerasClassifier(model = create_model, verbose = 0, batch_size = 20, epochs = 10,neuron1 = [4,8,16], neuron2 = [2,4,8])

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of grid search parameters

param_grid = dict(neuron1 = neuron1, neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(), verbose = 5 )
grid_result = grid.fit(X_standardized, y)

# %%
# Summarize the results
print('Best: {}, using : {}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{}, {}, using:{}'.format(mean,stdev,param))
# Out:
# Best: 0.776114081996435, using : {'neuron1': 8, 'neuron2': 8}
# 0.7630931160342925, 0.043627087599553034, using:{'neuron1': 4, 'neuron2': 2}
# 0.7696035990153638, 0.037971023630990544, using:{'neuron1': 4, 'neuron2': 4}
# 0.770927765045412, 0.040816915069101796, using:{'neuron1': 4, 'neuron2': 8}
# 0.7657159833630423, 0.03746651960427976, using:{'neuron1': 8, 'neuron2': 2}
# 0.7579067990832697, 0.04319670012975347, using:{'neuron1': 8, 'neuron2': 4}
# 0.776114081996435, 0.03658783021191213, using:{'neuron1': 8, 'neuron2': 8}
# 0.761811391223156, 0.04127295746546946, using:{'neuron1': 16, 'neuron2': 2}
# 0.7748153806977337, 0.03539795507181771, using:{'neuron1': 16, 'neuron2': 4}
# 0.7760971055088702, 0.03577667982162657, using:{'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# ## Training the model with Tuned values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
  model = Sequential()
  model.add(Dense(8, input_dim = 8, kernel_initializer = 'normal', activation = 'relu'))
  model.add(Dense(8, input_dim = 8, kernel_initializer = 'normal', activation = 'relu'))
  model.add(Dense(1, activation = 'sigmoid'))

  adam = Adam(learning_rate = 0.01)
  model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

# Create the model

model = KerasClassifier(model = create_model, verbose = 0, batch_size = 20, epochs = 10)

# fitting the model

model.fit(X_standardized, y)

# Predictions using trained model

y_predict = model.predict(X_standardized)

# Printing metrics

print(accuracy_score(y,y_predict))
# Out:
# 0.7981770833333334

# %% [markdown]
# ## Hyperparameters all at once
#
# This process is more efficient but computationally expensive

# %%
def create_model(learning_rate, dropout_rate, activation_function, kernel_initializer, neuron1, neuron2):
  model = Sequential()
  model.add(Dense(neuron1, input_dim = 8, kernel_initializer = kernel_initializer, activation = activation_function))
  model.add(Dropout(dropout_rate))
  model.add(Dense(neuron2, input_dim = 8, kernel_initializer = kernel_initializer, activation = activation_function))
  model.add(Dropout(dropout_rate))
  model.add(Dense(1, activation = 'sigmoid'))

  adam = Adam(learning_rate = learning_rate)
  model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

# Create the model

model = KerasClassifier(model = create_model, verbose = 0, batch_size = [10,20,40], epochs = [15, 50, 100], learning_rate = [0.03, 0.01, 0.02],
dropout_rate = [0.0, 0.01,0.02],
activation_function = ['softmax', 'relu', 'tanh', 'linear'],
kernel_initializer = ['uniform', 'normal', 'zero'],
neuron1 = [7, 8, 9],
neuron2 = [7,8,9])

# Defining the grid search parameters

batch_size = [10,20,40]
epochs = [15, 50, 100]
learning_rate = [0.03, 0.01, 0.02]
dropout_rate = [0.0, 0.01,0.02]
activation_function = ['softmax', 'relu', 'tanh', 'linear']
kernel_initializer = ['uniform', 'normal', 'zero']
neuron1 = [7, 8, 9]
neuron2 = [7,8,9]

# Make the dictionary of grid search parameters

param_grid = dict(batch_size = batch_size, epochs = epochs, learning_rate = learning_rate, dropout_rate = dropout_rate, activation_function = activation_function, kernel_initializer = kernel_initializer, neuron1 = neuron1, neuron2 = neuron2)

# Build and find the grid search CV

grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(), verbose=10)
grid_result = grid.fit(X_standardized, y)
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
# [CV 1/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7
# [CV 1/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7;, score=0.708 total time=   4.4s
# [CV 2/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7
# [CV 2/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7;, score=0.688 total time=   2.9s
# [CV 3/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7
# [CV 3/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7;, score=0.760 total time=   3.8s
# [CV 4/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7
# [CV 4/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7;, score=0.791 total time=   3.9s
# [CV 5/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7
# [CV 5/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=7;, score=0.739 total time=   3.0s
# [CV 1/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8
# [CV 1/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8;, score=0.708 total time=   3.8s
# [CV 2/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8
# [CV 2/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8;, score=0.701 total time=   2.7s
# [CV 3/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8
# [CV 3/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8;, score=0.779 total time=   3.9s
# [CV 4/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8
# [CV 4/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8;, score=0.778 total time=   3.1s
# [CV 5/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8
# [CV 5/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=8;, score=0.765 total time=   3.9s
# [CV 1/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9
# [CV 1/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9;, score=0.740 total time=   3.9s
# [CV 2/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9
# [CV 2/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9;, score=0.662 total time=   4.3s
# [CV 3/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9
# [CV 3/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9;, score=0.753 total time=   3.9s
# [CV 4/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9
# [CV 4/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9;, score=0.837 total time=   3.9s
# [CV 5/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9
# [CV 5/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=7, neuron2=9;, score=0.771 total time=   4.1s
# [CV 1/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7
# [CV 1/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7;, score=0.727 total time=   3.9s
# [CV 2/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7
# [CV 2/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7;, score=0.675 total time=   4.2s
# [CV 3/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7
# [CV 3/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7;, score=0.766 total time=   8.8s
# [CV 4/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7
# [CV 4/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7;, score=0.771 total time=   3.0s
# [CV 5/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7
# [CV 5/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=7;, score=0.778 total time=   3.0s
# [CV 1/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8
# [CV 1/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8;, score=0.721 total time=   6.6s
# [CV 2/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8
# [CV 2/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8;, score=0.695 total time=   3.0s
# [CV 3/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8
# [CV 3/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8;, score=0.753 total time=   3.0s
# [CV 4/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8
# [CV 4/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8;, score=0.837 total time=   4.0s
# [CV 5/5; 5/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8
# [CV 5/5; 5/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=8;, score=0.784 total time=   3.1s
# [CV 1/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9
# [CV 1/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9;, score=0.747 total time=   3.8s
# [CV 2/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9
# [CV 2/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9;, score=0.682 total time=   3.0s
# [CV 3/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9
# [CV 3/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9;, score=0.727 total time=   4.1s
# [CV 4/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9
# [CV 4/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9;, score=0.817 total time=   3.8s
# [CV 5/5; 6/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9
# [CV 5/5; 6/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=8, neuron2=9;, score=0.752 total time=   3.0s
# [CV 1/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7
# [CV 1/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7;, score=0.714 total time=   3.8s
# [CV 2/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7
# [CV 2/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7;, score=0.688 total time=   4.1s
# [CV 3/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7
# [CV 3/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7;, score=0.747 total time=   2.8s
# [CV 4/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7
# [CV 4/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7;, score=0.797 total time=   3.7s
# [CV 5/5; 7/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7
# [CV 5/5; 7/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=7;, score=0.765 total time=   3.8s
# [CV 1/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8
# [CV 1/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8;, score=0.721 total time=   4.0s
# [CV 2/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8
# [CV 2/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8;, score=0.695 total time=   3.7s
# [CV 3/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8
# [CV 3/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8;, score=0.760 total time=   2.8s
# [CV 4/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8
# [CV 4/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8;, score=0.830 total time=   4.0s
# [CV 5/5; 8/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8
# [CV 5/5; 8/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=8;, score=0.765 total time=   3.7s
# [CV 1/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9
# [CV 1/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9;, score=0.727 total time=   2.7s
# [CV 2/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9
# [CV 2/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9;, score=0.721 total time=   2.7s
# [CV 3/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9
# [CV 3/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9;, score=0.753 total time=   6.5s
# [CV 4/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9
# [CV 4/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9;, score=0.719 total time=   2.9s
# [CV 5/5; 9/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9
# [CV 5/5; 9/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.03, neuron1=9, neuron2=9;, score=0.752 total time=   3.7s
# [CV 1/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7
# [CV 1/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7;, score=0.721 total time=   3.9s
# [CV 2/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7
# [CV 2/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7;, score=0.688 total time=   3.8s
# [CV 3/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7
# [CV 3/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7;, score=0.753 total time=   2.7s
# [CV 4/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7
# [CV 4/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7;, score=0.837 total time=   3.7s
# [CV 5/5; 10/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7
# [CV 5/5; 10/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=7;, score=0.758 total time=   4.1s
# [CV 1/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8
# [CV 1/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8;, score=0.727 total time=   2.7s
# [CV 2/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8
# [CV 2/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8;, score=0.688 total time=   3.7s
# [CV 3/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8
# [CV 3/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8;, score=0.760 total time=   3.7s
# [CV 4/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8
# [CV 4/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8;, score=0.824 total time=   3.3s
# [CV 5/5; 11/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8
# [CV 5/5; 11/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=8;, score=0.765 total time=   3.8s
# [CV 1/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 1/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.727 total time=   2.8s
# [CV 2/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 2/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.675 total time=   3.1s
# [CV 3/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 3/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.753 total time=   3.4s
# [CV 4/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 4/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.830 total time=   3.7s
# [CV 5/5; 12/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 5/5; 12/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.765 total time=   3.7s
# [CV 1/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 1/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.714 total time=   3.7s
# [CV 2/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 2/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.688 total time=   3.1s
# [CV 3/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 3/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.766 total time=   2.7s
# [CV 4/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 4/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.850 total time=   3.7s
# [CV 5/5; 13/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 5/5; 13/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.758 total time=   3.4s
# [CV 1/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 1/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.734 total time=   3.0s
# [CV 2/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 2/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.669 total time=   2.7s
# [CV 3/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 3/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.753 total time=   3.7s
# [CV 4/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 4/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.863 total time=   3.8s
# [CV 5/5; 14/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 5/5; 14/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.758 total time=   2.9s
# [CV 1/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 1/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.721 total time=   3.6s
# [CV 2/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 2/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.701 total time=   3.7s
# [CV 3/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 3/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.753 total time=   4.0s
# [CV 4/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 4/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.824 total time=   3.7s
# [CV 5/5; 15/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 5/5; 15/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.758 total time=   2.7s
# [CV 1/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 1/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.714 total time=   7.3s
# [CV 2/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 2/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.682 total time=   3.3s
# [CV 3/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 3/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.753 total time=   3.0s
# [CV 4/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 4/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.843 total time=   3.1s
# [CV 5/5; 16/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 5/5; 16/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.797 total time=   4.2s
# [CV 1/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 1/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.727 total time=   6.6s
# [CV 2/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 2/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.695 total time=   3.6s
# [CV 3/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 3/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.747 total time=   4.2s
# [CV 4/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 4/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.817 total time=   3.7s
# [CV 5/5; 17/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 5/5; 17/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.752 total time=   3.0s
# [CV 1/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 1/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.721 total time=   4.1s
# [CV 2/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 2/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.688 total time=   3.2s
# [CV 3/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 3/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.760 total time=   3.0s
# [CV 4/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 4/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.817 total time=   3.7s
# [CV 5/5; 18/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 5/5; 18/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.765 total time=   4.0s
# [CV 1/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 1/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.701 total time=   3.7s
# [CV 2/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 2/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.669 total time=   3.8s
# [CV 3/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 3/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.779 total time=   4.0s
# [CV 4/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 4/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.830 total time=   4.5s
# [CV 5/5; 19/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 5/5; 19/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.765 total time=   3.7s
# [CV 1/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8
# [CV 1/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8;, score=0.727 total time=   3.8s
# [CV 2/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8
# [CV 2/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8;, score=0.675 total time=   4.1s
# [CV 3/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8
# [CV 3/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8;, score=0.753 total time=   2.7s
# [CV 4/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8
# [CV 4/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8;, score=0.850 total time=   3.7s
# [CV 5/5; 20/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8
# [CV 5/5; 20/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=8;, score=0.745 total time=   3.8s
# [CV 1/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9
# [CV 1/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9;, score=0.701 total time=   4.1s
# [CV 2/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9
# [CV 2/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9;, score=0.708 total time=   2.7s
# [CV 3/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9
# [CV 3/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9;, score=0.753 total time=   3.7s
# [CV 4/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9
# [CV 4/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9;, score=0.850 total time=   3.8s
# [CV 5/5; 21/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9
# [CV 5/5; 21/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=7, neuron2=9;, score=0.752 total time=   2.8s
# [CV 1/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7
# [CV 1/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7;, score=0.727 total time=   2.7s
# [CV 2/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7
# [CV 2/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7;, score=0.688 total time=   2.7s
# [CV 3/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7
# [CV 3/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7;, score=0.734 total time=   3.7s
# [CV 4/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7
# [CV 4/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7;, score=0.843 total time=   4.1s
# [CV 5/5; 22/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7
# [CV 5/5; 22/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=7;, score=0.758 total time=   2.6s
# [CV 1/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8
# [CV 1/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8;, score=0.727 total time=   2.7s
# [CV 2/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8
# [CV 2/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8;, score=0.662 total time=   3.8s
# [CV 3/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8
# [CV 3/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8;, score=0.753 total time=   3.9s
# [CV 4/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8
# [CV 4/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8;, score=0.817 total time=   2.6s
# [CV 5/5; 23/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8
# [CV 5/5; 23/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=8;, score=0.765 total time=   2.7s
# [CV 1/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9
# [CV 1/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9;, score=0.695 total time=   3.8s
# [CV 2/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9
# [CV 2/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9;, score=0.701 total time=   4.0s
# [CV 3/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9
# [CV 3/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9;, score=0.740 total time=   3.7s
# [CV 4/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9
# [CV 4/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9;, score=0.784 total time=   3.8s
# [CV 5/5; 24/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9
# [CV 5/5; 24/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=8, neuron2=9;, score=0.771 total time=   4.2s
# [CV 1/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7
# [CV 1/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7;, score=0.734 total time=   3.7s
# [CV 2/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7
# [CV 2/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7;, score=0.688 total time=   2.7s
# [CV 3/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7
# [CV 3/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7;, score=0.779 total time=   3.8s
# [CV 4/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7
# [CV 4/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7;, score=0.824 total time=   4.0s
# [CV 5/5; 25/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7
# [CV 5/5; 25/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=7;, score=0.778 total time=   2.9s
# [CV 1/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8
# [CV 1/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8;, score=0.714 total time=   3.7s
# [CV 2/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8
# [CV 2/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8;, score=0.682 total time=   4.0s
# [CV 3/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8
# [CV 3/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8;, score=0.740 total time=   2.7s
# [CV 4/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8
# [CV 4/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8;, score=0.797 total time=   3.7s
# [CV 5/5; 26/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8
# [CV 5/5; 26/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=8;, score=0.771 total time=   2.7s
# [CV 1/5; 27/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=9
# [CV 1/5; 27/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=9;, score=0.714 total time=   3.6s
# [CV 2/5; 27/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=9
# [CV 2/5; 27/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=15, kernel_initializer=uniform, learning_rate=0.02, neuron1=9, neuron2=9;, score=0.643 total time=   3.0s
# ...
# [CV 2/5; 119/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=8;, score=0.669 total time=   7.6s
# [CV 3/5; 119/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=8
# [CV 3/5; 119/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=8;, score=0.727 total time=   6.2s
# [CV 4/5; 119/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=8
# [CV 4/5; 119/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=8;, score=0.797 total time=  11.6s
# [CV 5/5; 119/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=8
# [CV 5/5; 119/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=8;, score=0.784 total time=  11.4s
# [CV 1/5; 120/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 1/5; 120/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.721 total time=   7.7s
# [CV 2/5; 120/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 2/5; 120/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.643 total time=   6.4s
# [CV 3/5; 120/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 3/5; 120/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.747 total time=   7.5s
# [CV 4/5; 120/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 4/5; 120/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.837 total time=  11.4s
# [CV 5/5; 120/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9
# [CV 5/5; 120/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=7, neuron2=9;, score=0.784 total time=   6.3s
# [CV 1/5; 121/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 1/5; 121/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.760 total time=  11.4s
# [CV 2/5; 121/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 2/5; 121/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.656 total time=   6.3s
# [CV 3/5; 121/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 3/5; 121/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.773 total time=  11.8s
# [CV 4/5; 121/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 4/5; 121/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.817 total time=  11.6s
# [CV 5/5; 121/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7
# [CV 5/5; 121/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=7;, score=0.771 total time=   7.4s
# [CV 1/5; 122/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 1/5; 122/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.766 total time=  11.3s
# [CV 2/5; 122/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 2/5; 122/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.656 total time=  11.3s
# [CV 3/5; 122/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 3/5; 122/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.779 total time=   6.3s
# [CV 4/5; 122/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 4/5; 122/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.797 total time=   7.5s
# [CV 5/5; 122/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8
# [CV 5/5; 122/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=8;, score=0.771 total time=   6.2s
# [CV 1/5; 123/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 1/5; 123/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.721 total time=   7.5s
# [CV 2/5; 123/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 2/5; 123/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.675 total time=   6.2s
# [CV 3/5; 123/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 3/5; 123/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.779 total time=  11.4s
# [CV 4/5; 123/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 4/5; 123/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.824 total time=   6.8s
# [CV 5/5; 123/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9
# [CV 5/5; 123/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=8, neuron2=9;, score=0.797 total time=  11.8s
# [CV 1/5; 124/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 1/5; 124/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.740 total time=  11.8s
# [CV 2/5; 124/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 2/5; 124/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.695 total time=   7.6s
# [CV 3/5; 124/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 3/5; 124/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.734 total time=   7.2s
# [CV 4/5; 124/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 4/5; 124/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.797 total time=  11.9s
# [CV 5/5; 124/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7
# [CV 5/5; 124/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=7;, score=0.778 total time=   7.9s
# [CV 1/5; 125/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 1/5; 125/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.734 total time=  11.3s
# [CV 2/5; 125/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 2/5; 125/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.675 total time=   6.2s
# [CV 3/5; 125/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 3/5; 125/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.773 total time=   7.6s
# [CV 4/5; 125/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 4/5; 125/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.784 total time=  11.4s
# [CV 5/5; 125/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8
# [CV 5/5; 125/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=8;, score=0.758 total time=  11.3s
# [CV 1/5; 126/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 1/5; 126/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.721 total time=   6.2s
# [CV 2/5; 126/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 2/5; 126/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.675 total time=  11.3s
# [CV 3/5; 126/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 3/5; 126/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.779 total time=   6.5s
# [CV 4/5; 126/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 4/5; 126/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.804 total time=  11.8s
# [CV 5/5; 126/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9
# [CV 5/5; 126/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.01, neuron1=9, neuron2=9;, score=0.791 total time=   7.4s
# [CV 1/5; 127/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 1/5; 127/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.721 total time=   6.1s
# [CV 2/5; 127/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 2/5; 127/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.695 total time=   7.2s
# [CV 3/5; 127/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 3/5; 127/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.792 total time=   6.3s
# [CV 4/5; 127/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 4/5; 127/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.758 total time=   7.3s
# [CV 5/5; 127/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7
# [CV 5/5; 127/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=7;, score=0.752 total time=  11.3s
# [CV 1/5; 128/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=50, kernel_initializer=normal, learning_rate=0.02, neuron1=7, neuron2=8

# %%
# Summarize the results
print('Best: {}, using : {}'.format(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{}, {}, using:{}'.format(mean,stdev,param))
# Out:
# Best: 0.776114081996435, using : {'neuron1': 8, 'neuron2': 8}
# 0.7630931160342925, 0.043627087599553034, using:{'neuron1': 4, 'neuron2': 2}
# 0.7696035990153638, 0.037971023630990544, using:{'neuron1': 4, 'neuron2': 4}
# 0.770927765045412, 0.040816915069101796, using:{'neuron1': 4, 'neuron2': 8}
# 0.7657159833630423, 0.03746651960427976, using:{'neuron1': 8, 'neuron2': 2}
# 0.7579067990832697, 0.04319670012975347, using:{'neuron1': 8, 'neuron2': 4}
# 0.776114081996435, 0.03658783021191213, using:{'neuron1': 8, 'neuron2': 8}
# 0.761811391223156, 0.04127295746546946, using:{'neuron1': 16, 'neuron2': 2}
# 0.7748153806977337, 0.03539795507181771, using:{'neuron1': 16, 'neuron2': 4}
# 0.7760971055088702, 0.03577667982162657, using:{'neuron1': 16, 'neuron2': 8}
