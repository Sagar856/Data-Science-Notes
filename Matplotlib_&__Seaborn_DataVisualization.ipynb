# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [-3,5,7]
y = [10,2,5]

# %%
fig = plt.figure(figsize=(15,3))

# %%
plt.plot(x,y)

# %%
fig, axes = plt.subplots(nrows=2,ncols=4)

# %%
import pandas as pd
import numpy as np

mtcars = pd.read_csv('/content/mtcars.csv')

# %%
mtcars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
pd.crosstab(mtcars.gear,mtcars.cyl)
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
pd.crosstab(mtcars.gear,mtcars.cyl).plot(kind='bar')
# Out:
# <Axes: xlabel='gear'>

# %%
mtcars['gear'].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
mtcars['gear'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='gear'>

# %%
plt.scatter(mtcars.mpg,mtcars.qsec)

# %%
plt.hist(mtcars['mpg'])
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(mtcars['mpg'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79856cde6380>,
#   <matplotlib.lines.Line2D at 0x79856cde6620>],
#  'caps': [<matplotlib.lines.Line2D at 0x79856cde68c0>,
#   <matplotlib.lines.Line2D at 0x79856cde6b60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x79856cde60e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x79856cde6e00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79856cde70a0>],
#  'means': []}

# %%
plt.violinplot(mtcars['mpg'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x79856d38d9f0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x79856d38d480>,
#  'cmins': <matplotlib.collections.LineCollection at 0x79856d38dc30>,
#  'cbars': <matplotlib.collections.LineCollection at 0x79856d38ece0>}

# %% [markdown]
# # **Seaborn**

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.stripplot(y='tip',data=tips)
# Out:
# <Axes: ylabel='tip'>
